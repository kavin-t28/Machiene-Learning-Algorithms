# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("house_pred.csv")
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
target = data['SalePrice']
data = data.drop(['Id','Alley','PoolQC','Fence','MiscFeature','SalePrice'],axis=1)

# %%
target
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
obj = data.select_dtypes(include=object).columns
num = data.select_dtypes(exclude=object).columns

# %%
for i in num:
    data[i].fillna(data[i].mean(), inplace=True)

# %%
for i in data.columns[data.isna().sum()>0]:
    data[i].fillna(None, method='ffill',inplace=True)
# Out:
# /tmp/ipykernel_4023/897364158.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data[i].fillna(None, method='ffill',inplace=True)

# %%
data
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             60       RL         65.0     8450   Pave      Reg         Lvl
# 1             20       RL         80.0     9600   Pave      Reg         Lvl
# 2             60       RL         68.0    11250   Pave      IR1         Lvl
# 3             70       RL         60.0     9550   Pave      IR1         Lvl
# 4             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1455          60       RL         62.0     7917   Pave      Reg         Lvl
# 1456          20       RL         85.0    13175   Pave      Reg         Lvl
# 1457          70       RL         66.0     9042   Pave      Reg         Lvl
# 1458          20       RL         68.0     9717   Pave      Reg         Lvl
# 1459          20       RL         75.0     9937   Pave      Reg         Lvl
#
# ...

# %%
# for i in data.select_dtypes(include=object):
#     data = pd.concat((data, pd.get_dummies(data[i], drop_first=True)), axis=1)
#     data.drop(i, axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()

for i in data.select_dtypes(include=object):
        data[i]= enc.fit_transform(data[i])

# %%
# from sklearn.preprocessing import MinMaxScaler

# data[num]= MinMaxScaler().fit_transform(data[num])

# %%
target
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

xtr, xtst, ytr, ytst = train_test_split(data, target, test_size=0.3)

lr = LinearRegression()

# %%
model = lr.fit(xtr, ytr)

# %%
lr.score(xtr, ytr)
# Out:
# 0.8548231765616698

# %%
# Test

test = pd.read_csv("test.csv")
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1205          20       RL         78.0    10140   Pave   NaN      Reg
# 1  1206          20       RL         90.0    14684   Pave   NaN      IR1
# 2  1207          20       RH          NaN     8900   Pave   NaN      Reg
# 3  1208          20       RL         70.0     9135   Pave   NaN      Reg
# 4  1209          20       RL         70.0     7763   Pave   NaN      Reg
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
test = test.drop(['Id','Alley','PoolQC','Fence','MiscFeature'],axis=1)

# %%
obj = test.select_dtypes(include=object).columns
num = test.select_dtypes(exclude=object).columns

# %%
for i in num:
    test[i].fillna(test[i].mean(), inplace=True)

# %%
for i in test.columns[test.isna().sum()>0]:
    test[i].fillna(None,method='ffill',inplace=True)
# Out:
# /tmp/ipykernel_4023/2465477295.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   test[i].fillna(None,method='ffill',inplace=True)

# %%
test
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0            20       RL     78.00000    10140   Pave      Reg         Lvl
# 1            20       RL     90.00000    14684   Pave      IR1         Lvl
# 2            20       RH     69.89372     8900   Pave      Reg         Lvl
# 3            20       RL     70.00000     9135   Pave      Reg         Lvl
# 4            20       RL     70.00000     7763   Pave      Reg         Lvl
# ..          ...      ...          ...      ...    ...      ...         ...
# 251          60       RL     62.00000     7917   Pave      Reg         Lvl
# 252          20       RL     85.00000    13175   Pave      Reg         Lvl
# 253          70       RL     66.00000     9042   Pave      Reg         Lvl
# 254          20       RL     68.00000     9717   Pave      Reg         Lvl
# 255          20       RL     75.00000     9937   Pave      Reg         Lvl
#
# ...

# %%
for i in test.select_dtypes(include=object):
        test[i]= enc.fit_transform(test[i])

test[num]= MinMaxScaler().fit_transform(test[num])

# %%
test
# Out:
#      MSSubClass  MSZoning  LotFrontage   LotArea  Street  LotShape  \
# 0      0.000000         3     0.195205  0.138034       0         3
# 1      0.000000         3     0.236301  0.210909       0         0
# 2      0.000000         2     0.167444  0.118148       0         3
# 3      0.000000         3     0.167808  0.121917       0         3
# 4      0.000000         3     0.167808  0.099913       0         3
# ..          ...       ...          ...       ...     ...       ...
# 251    0.235294         3     0.140411  0.102383       0         3
# 252    0.000000         3     0.219178  0.186708       0         3
# 253    0.294118         3     0.154110  0.120425       0         3
# 254    0.000000         3     0.160959  0.131251       0         3
# 255    0.000000         3     0.184932  0.134779       0         3
#
#      LandContour  Utilities  LotConfig  LandSlope  ...  OpenPorchSF  \
# 0              3          0          4          0  ...     0.160878
# ...

# %%
lr.predict(test)
# Out:
# array([2374397.7823126 , 2405341.37918893, 2359106.12254183,
#        2400671.14841157, 2353786.45293002, 2431705.93862636,
#        2391453.74318162, 2396942.99770165, 2351470.21793674,
#        2373950.99827609, 2369506.49830953, 2353733.63272272,
#        2340114.07134491, 2415168.25621026, 2359582.86444596,
#        2321783.34852073, 2336348.42068657, 2361452.77745387,
#        2368168.17859395, 2350503.52489133, 2407632.01017906,
#        2378758.69633966, 2409763.17864379, 2375750.01290774,
#        2464062.84773726, 2352592.4080355 , 2361649.27946615,
#        2365235.50017432, 2358132.05648811, 2351841.17316226,
#        2334723.58116849, 2346144.33546265, 2382294.48955102,
#        2394045.29389102, 2368299.92623603, 2430346.5134921 ,
#        2397122.65293594, 2419853.50108703, 2385260.38757655,
#        2480872.81279449, 2394104.05626369, 2360829.00598377,
#        2399901.77862979, 2374678.00629898, 2348282.11758411,
# ...

# %%
test
# Out:
#      MSSubClass  MSZoning  LotFrontage   LotArea  Street  LotShape  \
# 0      0.000000         3     0.195205  0.138034       0         3
# 1      0.000000         3     0.236301  0.210909       0         0
# 2      0.000000         2     0.167444  0.118148       0         3
# 3      0.000000         3     0.167808  0.121917       0         3
# 4      0.000000         3     0.167808  0.099913       0         3
# ..          ...       ...          ...       ...     ...       ...
# 251    0.235294         3     0.140411  0.102383       0         3
# 252    0.000000         3     0.219178  0.186708       0         3
# 253    0.294118         3     0.154110  0.120425       0         3
# 254    0.000000         3     0.160959  0.131251       0         3
# 255    0.000000         3     0.184932  0.134779       0         3
#
#      LandContour  Utilities  LotConfig  LandSlope  ...  OpenPorchSF  \
# 0              3          0          4          0  ...     0.160878
# ...
